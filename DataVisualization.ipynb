# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
veri = pd.read_csv("olimpiyatlar_temizlenmis.csv")
veri.head()
# Out:
#                        isim cinsiyet   yas     boy   kilo           takim  \
# 0      Edgar Lindenau Aabye        M  34.0  182.48  95.62  Denmark/Sweden
# 1      Arvo Ossian Aaltonen        M  30.0  182.01  76.69         Finland
# 2      Arvo Ossian Aaltonen        M  30.0  177.00  75.00         Finland
# 3  Juhamatti Tapio Aaltonen        M  28.0  184.00  85.00         Finland
# 4   Paavo Johannes Aaltonen        M  28.0  175.00  64.00         Finland
#
#    uok     yil   sezon      sehir        spor  \
# 0  DEN  1900.0  Summer      Paris  Tug-Of-War
# 1  FIN  1920.0  Summer  Antwerpen    Swimming
# 2  FIN  1920.0  Summer  Antwerpen    Swimming
# 3  FIN  2014.0  Winter      Sochi  Ice Hockey
# 4  FIN  1948.0  Summer     London  Gymnastics
#
#                                  etkinlik madalya
# 0             Tug-Of-War Men's Tug-Of-War    Gold
# 1  Swimming Men's 200 metres Breaststroke  Bronze
# 2  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
def sacilimGrafikCiz():
    sns.scatterplot(x='boy', y='kilo', data=veri)
    plt.title('Boy ve Ağırlık İlişkisi - Beyaz Izgara Tema')
    plt.show()

sacilimGrafikCiz()

# %%
sns.set_style("darkgrid")
sacilimGrafikCiz()

# %%
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri)
plt.title("Madalyaya göre boy ve ağırlık dağılımı")
plt.show()

# %%
sns.set_style("whitegrid")
sns.scatterplot(x='boy', y='kilo', hue='cinsiyet', style='madalya',size='yas', sizes=(15,200), data=veri)
plt.xlabel('Boy')
plt.ylabel('Kilo')
plt.title("Madalyalı sporcuların boy-ağırlık değişimi")
plt.show()

# %%
sns.regplot(x='boy', y='kilo', data=veri, marker='+', scatter_kws={'alpha':0.2})
plt.title('Boy ve Ağırlık dağılımı')
plt.show()

# %%
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette='Set1')
plt.title('Madalyaya göre Boy ve Ağırlık dağılımı')
plt.show()

# %%
sns.scatterplot(x='boy', y='kilo', hue='madalya', data=veri, palette='rocket')
plt.title('Madalyaya göre Boy ve Ağırlık dağılımı')
plt.show()

# %%
sns.lineplot(x='boy', y='kilo', data=veri)
plt.title('Boy ve Kilo')
plt.show()

# %%
sns.lineplot(x='boy', y='kilo', hue='cinsiyet', data=veri)
plt.title('Cinsiyete göre Boy ve Kilo')
plt.show()

# %%
sns.lineplot(x='boy', y='kilo', hue='madalya', data=veri)
plt.title('Madalya göre Boy ve Kilo')
plt.show()

# %%
sns.displot(veri, x='kilo')
plt.ylabel("Frekans")
plt.title("Ağırlık Histogramı")
plt.show()

# %%
sns.displot(veri, x='kilo', hue='cinsiyet')
plt.ylabel('Frekans')
plt.title('Cinsiyete göre ağırlık histogramı')
plt.show()

# %%
sns.displot(veri, x='kilo', col='cinsiyet', multiple="dodge")
plt.show()

# %%
sns.displot(veri, x='kilo', y='boy', kind='kde')
plt.xlabel('Ağırlık')
plt.ylabel('Boy')
plt.title('Ağırlık-Boy histogramı')
plt.show()

# %%
sns.kdeplot(data=veri, x='kilo', y='boy', hue='cinsiyet', fill=True)
plt.xlabel('Ağırlık')
plt.ylabel('Boy')
plt.title('Cinsiyete göre Ağırlık-Boy histogramı')
plt.show()

# %%
sns.barplot(x='madalya', y='boy', data=veri)
plt.title("madalyalara göre boy grafikleri")
plt.show()

# %%
sns.barplot(x='madalya', y='boy', data=veri, hue='cinsiyet')
plt.title("madalyalara göre boy grafikleri")
plt.show()

# %%
sns.catplot(x='madalya', y='yas', hue='cinsiyet', col='sezon', data=veri, kind='bar', height=4, aspect=0.7)
plt.show()

# %%
sns.boxplot(x='sezon', y='boy', data=veri)
plt.show()

# %%
sns.boxplot(x='sezon', y='boy', hue='cinsiyet', data=veri, palette='Set2')
plt.show()

# %%
veri_gecici = veri.loc[:,["yas","kilo","boy"]]
sns.boxplot(data=veri_gecici, orient='h', palette="Set2")
plt.show()

# %%
sns.catplot(x='sezon', y='boy', hue="cinsiyet", col="madalya", data=veri, kind="box", height=4, aspect=0.7)
plt.show()

# %%
sayisal_sutunlar = veri.select_dtypes(include=['float64', 'int64', 'uint8'])

# Korelasyon matrisini hesaplama
corr_matrix = sayisal_sutunlar.corr()
sns.heatmap(corr_matrix, annot=True, linewidths=0.5, fmt='.1f')
plt.show()

# %%
sns.violinplot(x='sezon', y='boy', data=veri)
plt.show()

# %%
sns.violinplot(x='sezon', y='boy', hue='cinsiyet', data=veri)
plt.show()

# %%
sns.violinplot(x='sezon', y='boy', data=veri, hue='cinsiyet', split=True)
plt.show()

# %%
sns.catplot(x='sezon', y='boy', hue='cinsiyet', col='madalya',
            data=veri, kind='violin', split=True, height=4, aspect=0.7)
plt.show()

# %%
sns.jointplot(data=veri, x='kilo', y='boy', hue='sezon', kind='kde')
plt.show()

# %%
g = sns.JointGrid(data=veri, x='kilo', y='boy')
g.plot_joint(sns.histplot)
g.plot_marginals(sns.boxplot)
plt.show()

# %%
sns.pairplot(veri)
plt.show()

# %%
g = sns.PairGrid(veri)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %%
sns.countplot(x='sehir', data=veri)
plt.xticks(rotation=90)
plt.show()
